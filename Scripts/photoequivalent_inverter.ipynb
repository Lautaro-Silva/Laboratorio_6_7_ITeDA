# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data from the file
file_path = r'C:\Users\smili\OneDrive\Documents\GitHub\Laboratorio_6_7_ITeDA\LTSpice\Agosto - Version nueva de las simulaciones\photon_data_1_photoequivalent.txt'
data = np.loadtxt(file_path, delimiter=',')

# Split the data into time (x-values) and signal (y-values)
time = data[:, 0]
signal = data[:, 1]

# Reflect the signal over the x-axis (invert y-values)
reflected_signal = -signal

# Plot original and reflected signals
plt.figure(figsize=(10, 6))
plt.plot(time, signal, label='Original Signal', color='blue')
plt.plot(time, reflected_signal, label='Reflected Signal', color='red', linestyle='--')
plt.xlabel('Time (s)')
plt.ylabel('Signal')
plt.title('Original vs Reflected Signal')
plt.legend()
plt.grid(True)
plt.show()

# Save the reflected data to a new file
output_file_path = r'C:\Users\smili\OneDrive\Documents\GitHub\Laboratorio_6_7_ITeDA\LTSpice\Septiembre - Analisis de fuente de problemas\photon_data_1_photoequivalent_reflected.txt'
reflected_data = np.column_stack((time, reflected_signal))
np.savetxt(output_file_path, reflected_data, delimiter=',')

# %%
# Load the data from the file
file_path = r'C:\Users\smili\OneDrive\Documents\GitHub\Laboratorio_6_7_ITeDA\LTSpice\Agosto - Version nueva de las simulaciones\photon_data_2_photoequivalent.txt'
data = np.loadtxt(file_path, delimiter=',')

# Split the data into time (x-values) and signal (y-values)
time = data[:, 0]
signal = data[:, 1]

# Reflect the signal over the x-axis (invert y-values)
reflected_signal = -signal

# Plot original and reflected signals
plt.figure(figsize=(10, 6))
plt.plot(time, signal, label='Original Signal', color='blue')
plt.plot(time, reflected_signal, label='Reflected Signal', color='red', linestyle='--')
plt.xlabel('Time (s)')
plt.ylabel('Signal')
plt.title('Original vs Reflected Signal')
plt.legend()
plt.grid(True)
plt.show()

# Save the reflected data to a new file
output_file_path = r'C:\Users\smili\OneDrive\Documents\GitHub\Laboratorio_6_7_ITeDA\LTSpice\Septiembre - Analisis de fuente de problemas\photon_data_2_photoequivalent_reflected.txt'
reflected_data = np.column_stack((time, reflected_signal))
np.savetxt(output_file_path, reflected_data, delimiter=',')

# %%
# Load the data from the file
file_path = r'C:\Users\smili\OneDrive\Documents\GitHub\Laboratorio_6_7_ITeDA\LTSpice\Agosto - Version nueva de las simulaciones\photon_data_3_photoequivalent.txt'
data = np.loadtxt(file_path, delimiter=',')

# Split the data into time (x-values) and signal (y-values)
time = data[:, 0]
signal = data[:, 1]

# Reflect the signal over the x-axis (invert y-values)
reflected_signal = -signal

# Plot original and reflected signals
plt.figure(figsize=(10, 6))
plt.plot(time, signal, label='Original Signal', color='blue')
plt.plot(time, reflected_signal, label='Reflected Signal', color='red', linestyle='--')
plt.xlabel('Time (s)')
plt.ylabel('Signal')
plt.title('Original vs Reflected Signal')
plt.legend()
plt.grid(True)
plt.show()

# Save the reflected data to a new file
output_file_path = r'C:\Users\smili\OneDrive\Documents\GitHub\Laboratorio_6_7_ITeDA\LTSpice\Septiembre - Analisis de fuente de problemas\photon_data_3_photoequivalent_reflected.txt'
reflected_data = np.column_stack((time, reflected_signal))
np.savetxt(output_file_path, reflected_data, delimiter=',')
