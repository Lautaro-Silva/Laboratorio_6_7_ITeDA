# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Plots para la imagen representativa

# %%
# Primer ploteo los datos de la señal sola

# Read the text file, specifying the delimiter as a comma
df = pd.read_csv('C:/Users/Usuario/OneDrive/Desktop/ITeDA/Presentacion-Informe Avance de Proyecto/Datos Diagrama/photon_data_25_combined.txt', header=None)

# Print the first few rows of the dataframe to check the data
print(df.head())

# Extract the time and amplitude values
t_values = df[0]  # First column
data = df[1]     # Second column

# Plot the resulting function
plt.plot(t_values, data, color='red', label='SiPM output Signal', linewidth=2)
plt.title('Plot of Muon Signal conformed of 25PE')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (V)')
plt.xlim(0, 1.4e-7)
plt.grid(True)
plt.legend()
plt.savefig('muon_signal.png', dpi=1000)
# Out:
#               0    1
# 0  0.000000e+00  0.0
# 1  5.001667e-11  0.0
# 2  1.000333e-10  0.0
# 3  1.500500e-10  0.0
# 4  2.000667e-10  0.0

# %%
# PREAMP

# Read the text file, specifying the delimiter as a comma
df = pd.read_csv('C:/Users/Usuario/OneDrive/Desktop/ITeDA/Presentacion-Informe Avance de Proyecto/Datos Diagrama/photon_data_25_combined_preamp.txt', delimiter='	', skiprows=1, header=None)

# Print the first few rows of the dataframe to check the data
print(df.head())

# Extract the time and amplitude values
t_values = df[0]
data = df[1]*(-1)     # Invierto

# Plot the resulting function
plt.plot(t_values, data, color='red', label='PreAmp output Signal', linewidth=2)
plt.title('Plot of Muon Signal conformed of 25PE')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (V)')
plt.xlim(0, 1.4e-7)
plt.grid(True)
plt.legend()
plt.savefig('muon_signal_post_preamp.png', dpi=1000)
# Out:
#               0             1
# 0  0.000000e+00  0.000000e+00
# 1  8.052684e-10 -3.373453e-08
# 2  8.345067e-10 -6.960923e-07
# 3  8.637451e-10 -2.181501e-06
# 4  8.929834e-10 -4.489962e-06

# %%
# FASTSHAPER

# Read the text file, specifying the delimiter as a comma
df = pd.read_csv('C:/Users/Usuario/OneDrive/Desktop/ITeDA/Presentacion-Informe Avance de Proyecto/Datos Diagrama/photon_data_25_combined_fs.txt', delimiter='	', skiprows=1, header=None)

# Print the first few rows of the dataframe to check the data
print(df.head())

# Extract the time and amplitude values
t_values = df[0]
data = df[1]

# Plot the resulting function
plt.plot(t_values, data, color='red', label='PreAmp + FastShaper output Signal', linewidth=2)
plt.title('Plot of Muon Signal conformed of 25PE')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (V)')
plt.xlim(0, 2e-7)
plt.grid(True)
plt.legend()
plt.savefig('muon_signal_post_fs.png', dpi=1000)
# Out:
#               0             1
# 0  0.000000e+00  0.000000e+00
# 1  8.052684e-10  5.839728e-11
# 2  8.345067e-10 -1.462869e-07
# 3  8.637451e-10 -1.265915e-07
# 4  8.929834e-10  5.914469e-08

# %%
# DISCRIMINADOR

# Read the text file, specifying the delimiter as a comma
df = pd.read_csv('C:/Users/Usuario/OneDrive/Desktop/ITeDA/Presentacion-Informe Avance de Proyecto/Datos Diagrama/photon_data_25_combined_discri.txt', delimiter='	', skiprows=1, header=None)

# Print the first few rows of the dataframe to check the data
print(df.head())

# Extract the time and amplitude values
t_values = df[0] 
data = df[1]     

# Plot the resulting function
plt.plot(t_values, data, color='red', label='Discriminator output Signal', linewidth=2)
plt.title('Plot of Muon Signal conformed of 25PE')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (V)')
plt.xlim(0, 1.5e-7)
plt.grid(True)
plt.legend()
plt.savefig('muon_signal_post_discri.png', dpi=1000)
# Out:
#               0             1
# 0  0.000000e+00  9.999999e-08
# 1  8.052684e-10  9.999999e-08
# 2  8.345067e-10  9.999999e-08
# 3  8.637451e-10  9.999999e-08
# 4  8.929834e-10  9.999999e-08

# %%
# Read the text file, specifying the delimiter as a tab
df = pd.read_csv('C:/Users/Usuario/OneDrive/Desktop/ITeDA/Presentacion-Informe Avance de Proyecto/Datos Diagrama/photon_data_25_combined_discri.txt', delimiter='\t', skiprows=1, header=None)

# Print the first few rows of the dataframe to check the data
print(df.head())

# Extract the time and amplitude values
t_values = df[0]  
data = df[1]    

# Plot the resulting function

plt.figure(figsize=(10, 6))

plt.plot(t_values, data, color='red', linewidth=2)

# Add vertical lines separated by 3.125 ns starting from 0 on the x-axis
zone_interval = 3.125e-9  # 3.125 ns in seconds
start_time = t_values.iloc[0]  # Adjust this as needed based on the start of your signal

# Calculate the positions of the vertical lines
current_position = start_time
while current_position <= t_values.iloc[-1]:
    plt.axvline(x=current_position, color='blue', linestyle='--', linewidth=1)
    current_position += zone_interval

plt.title('Plot of Muon Signal conformed of 25PE')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (V)')
plt.xlim(0, 0.7e-7)
plt.grid(True)
plt.savefig('muon_signal_post_ones.png', dpi=1000)
plt.show()
# Out:
#               0             1
# 0  0.000000e+00  9.999999e-08
# 1  8.052684e-10  9.999999e-08
# 2  8.345067e-10  9.999999e-08
# 3  8.637451e-10  9.999999e-08
# 4  8.929834e-10  9.999999e-08

# %% [markdown]
# ## Bode PreAmp simulado

# %%
# Read the text file, using tab as the separator, and specify encoding
df = pd.read_csv('C:/Users/Usuario/OneDrive/Desktop/ITeDA/Presentacion-Informe Avance de Proyecto/Datos Bode/Bode_data_preamp_sin_capacitores.txt', sep="\t", skiprows=1, names=['Frequency', 'V(out_preamp)'], encoding='ISO-8859-1')

# Check the first few rows to understand the structure
print(df.head())
    
# Extract the first element of V(out_fs), which is the dB value
df['Attenuation'] = df['V(out_preamp)'].apply(lambda x: float(x.split(',')[0][1:].replace('dB', '').strip()))  # Clean the dB part

# Plotting the Bode diagram
plt.plot(df['Frequency'], df['Attenuation'], color='red')
plt.xscale('log')
plt.xlim(7e5, 1e10)

# Horizontal line at 17 dB
plt.axhline(y=17, color='blue', linestyle='--', label='17dB')

# Find the intersection point(s)
intersection_indices = np.where(np.diff(np.sign(df['Attenuation'] - 17)))[0]
if len(intersection_indices) > 0:
    freq_intersection = df['Frequency'].iloc[intersection_indices]
    for freq in freq_intersection:
        # Vertical line at intersection point
        plt.axvline(x=freq, color='green', linestyle='--')

        # Annotation
        plt.annotate(f'Freq: {freq:.2e} Hz', 
                     xy=(freq, 17), 
                     xytext=(5, 5), 
                     textcoords='offset points', 
                     arrowprops=dict(facecolor='black', arrowstyle='->'),
                     fontsize=10, color='black', 
                     bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

plt.title('Simulated Bode Diagram of the PreAmplifier', size=15)
plt.xlabel('Frequency (Hz)', size=13)
plt.ylabel('Attenuation (dB)', size=13)
plt.grid()
plt.legend()
plt.savefig('frequency_vs_attenuation_preamp.pdf', dpi=1000)
plt.show()
# Out:
#    Frequency                                   V(out_preamp)
# 0   1.000000  (1.99999044536548e+01dB,1.79999993697522e+02°)
# 1   1.002305  (1.99999044536548e+01dB,1.79999993682993e+02°)
# 2   1.004616  (1.99999044536548e+01dB,1.79999993668431e+02°)
# 3   1.006932  (1.99999044536548e+01dB,1.79999993653835e+02°)
# 4   1.009253  (1.99999044536548e+01dB,1.79999993639206e+02°)

# %% [markdown]
# ## Bode FastShaper + comparacion con fabricante

# %%
# Read the text file, using tab as the separator, and specify encoding
df = pd.read_csv('C:/Users/Usuario/OneDrive/Desktop/ITeDA/Presentacion-Informe Avance de Proyecto/Datos Bode/Bode_data_fastshaper.txt', sep="\t", skiprows=1, names=['Frequency', 'V(out_preamp)'], encoding='ISO-8859-1')

# Extract the first element of V(out_fs), which is the dB value
df['Attenuation'] = df['V(out_preamp)'].apply(lambda x: float(x.split(',')[0][1:].replace('dB', '').strip()))  # Clean the dB part

# Find the point with the highest attenuation
max_attenuation_idx = df['Attenuation'].idxmax()
max_attenuation_freq = df['Frequency'].iloc[max_attenuation_idx]
max_attenuation_value = df['Attenuation'].iloc[max_attenuation_idx]

# Plotting the Bode diagram
plt.plot(df['Frequency'], df['Attenuation'], color='red')
plt.xscale('log')
plt.xlim(7e5, 1e10)

# Mark the highest attenuation point
plt.scatter(max_attenuation_freq, max_attenuation_value, color='blue', zorder=5)

# Add a vertical line at the point of highest attenuation
plt.axvline(x=max_attenuation_freq, color='green', linestyle='--')

# Annotation for the highest attenuation point
plt.annotate(f'Freq: {max_attenuation_freq:.2e} Hz', 
             xy=(max_attenuation_freq, max_attenuation_value), 
             xytext=(5, 5), 
             textcoords='offset points', 
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10, color='black', 
             bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

plt.title('Simulated Bode Diagram of the FastShaper', size=15)
plt.xlabel('Frequency (Hz)', size=13)
plt.ylabel('Attenuation (dB)', size=13)
plt.grid()
plt.savefig('frequency_vs_attenuation_fs.pdf', dpi=1000)
plt.show()

# %%
# Read the text file for the simulated data
df = pd.read_csv('C:/Users/Usuario/OneDrive/Desktop/ITeDA/Presentacion-Informe Avance de Proyecto/Datos Bode/Bode_data_fastshaper.txt', sep="\t", skiprows=1, names=['Frequency', 'V(out_preamp)'], encoding='ISO-8859-1')

# Extract the first element of V(out_fs), which is the dB value
df['Attenuation'] = df['V(out_preamp)'].apply(lambda x: float(x.split(',')[0][1:].replace('dB', '').strip())) -  6.8  # Clean the dB part

# Find the point with the highest attenuation for simulated data
max_attenuation_idx = df['Attenuation'].idxmax()
max_attenuation_freq = df['Frequency'].iloc[max_attenuation_idx]
max_attenuation_value = df['Attenuation'].iloc[max_attenuation_idx]

# Read the manufacturer data
df1 = pd.read_csv('C:/Users/Usuario/OneDrive/Desktop/ITeDA/Bode-Manufacturer + Código/mag_fasthaper.csv', names=("frec", "atenuation"))
df1 = df1.tail(-1)
df1 = df1.astype('float')

# Find the point with the highest attenuation for manufacturer data
max_manufacturer_idx = df1['atenuation'].idxmax()  # Index of the maximum value

# Manually choose the previous point if it exists
if max_manufacturer_idx > 0:
    max_manufacturer_idx -= 1  # Choose the previous index

max_manufacturer_freq = df1['frec'].iloc[max_manufacturer_idx]
max_manufacturer_value = df1['atenuation'].iloc[max_manufacturer_idx]



# Create a larger figure
plt.figure(figsize=(12, 8))  # Set width and height in inches

# Scatter plot for manufacturer data
df1.plot(kind="scatter",
          x='frec',
          y='atenuation',
          color='blue', label='Manufacturer')

# Plotting the Bode diagram for simulation
plt.plot(df['Frequency'], df['Attenuation'], color='red', label='Simulation')


# Mark the highest attenuation point for simulated data
plt.scatter(max_attenuation_freq, max_attenuation_value, color='red', zorder=5)

# Add a vertical line at the point of highest attenuation for simulated data
plt.axvline(x=max_attenuation_freq, color='red', linestyle='--')

# Annotation for the highest attenuation point for simulated data
plt.annotate(f'Freq: {max_attenuation_freq:.2e} Hz', 
             xy=(max_attenuation_freq, max_attenuation_value), 
             xytext=(-120, -3), 
             textcoords='offset points', 
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10, color='black', 
             bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))


# Mark the highest attenuation point for manufacturer data
plt.scatter(max_manufacturer_freq, max_manufacturer_value, color='blue', zorder=5)

# Add a vertical line at the point of highest attenuation for manufacturer data
plt.axvline(x=max_manufacturer_freq, color='blue', linestyle='--')

# Annotation for the highest attenuation point for manufacturer data
plt.annotate(f'Freq: {max_manufacturer_freq:.2e} Hz', 
             xy=(max_manufacturer_freq, max_manufacturer_value), 
             xytext=(30, -3), 
             textcoords='offset points', 
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10, color='black', 
             bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))  # Corrected here


# Set titles and labels
plt.title('Comparison of Simulated and Manufacturer Bode Diagram of the FastShaper', size=11)
plt.xlabel('Frequency (Hz)', size=9)
plt.ylabel('Attenuation (dB)', size=9)
plt.xscale('log')
plt.xlim(1e5, 1e10)
plt.ylim(-50, 28)
plt.grid()
plt.legend(loc='lower left')  # Ensure legend is shown
plt.savefig('frequency_vs_attenuation_fs_comparison_normalized.pdf', dpi=1000)
plt.show()

# Debugging information
print(f'Max Simulated Attenuation: {max_attenuation_value} at Frequency: {max_attenuation_freq:.2e} Hz')
print(f'Max Manufacturer Attenuation: {max_manufacturer_value} at Frequency: {max_manufacturer_freq:.2e} Hz')
# Out:
# Max Simulated Attenuation: 23.5803130316195 at Frequency: 1.29e+07 Hz
# Max Manufacturer Attenuation: 23.48637507749746 at Frequency: 2.75e+07 Hz

# %% [markdown]
# ## Bode simulados cadena entera + comparacion con el simulado + comparacion con medicion directa

# %%
df2 = pd.read_csv('C:/Users/Usuario/Documents/Laboratorio_6_7_ITeDA/Bode-Manufacturer + Código/mag_fschain.csv', names=("frec", "atenuation"))
df2 = df2.tail(-1)
df2 = df2.astype('float')


# scatter plot
df2.plot(#kind="scatter",
         x='frec',
        y='atenuation',
        color='blue',
        label='Manufacturer')
 

# Read the text file, using tab as the separator, and specify encoding
df = pd.read_csv('C:/Users/Usuario/Documents/Laboratorio_6_7_ITeDA/Presentacion-Informe Avance de Proyecto/Datos Bode/Bode_data_full_chain.txt', sep="\t", skiprows=1, names=['Frequency', 'V(out_fs)'], encoding='ISO-8859-1')

# Extract the first element of V(out_fs), which is the dB value
df['Attenuation'] = df['V(out_fs)'].apply(lambda x: float(x.split(',')[0][1:].replace('dB', '').strip())) + 6.5  # Clean the dB part

# Plotting
plt.plot(df['Frequency'], df['Attenuation'], color='red', label='Simulated')
plt.xscale('log')  # Set x-axis to log scale
plt.title('Simulated Bode Diagram of the whole chain')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Attenuation (dB)')
plt.xlim(1e5, 5e8)
plt.ylim(0,55)
plt.legend()
plt.grid()
plt.savefig('frequency_vs_attenuation_whole_chain_comparison.png', dpi=1000)
plt.show()

# %%
# Load manufacturer data
df2 = pd.read_csv('C:/Users/Usuario/Documents/Laboratorio_6_7_ITeDA//Bode-Manufacturer + Código/mag_fschain.csv', names=("frec", "atenuation"))
df2 = df2.tail(-1)
df2 = df2.astype('float')

# Find the peak attenuation for manufacturer data (manual selection of the previous point)
max_manufacturer_idx = df2['atenuation'].idxmax() - 1  # Moving to the previous point
max_manufacturer_freq = df2['frec'].iloc[max_manufacturer_idx]
max_manufacturer_value = df2['atenuation'].iloc[max_manufacturer_idx]

# Load simulated data
df = pd.read_csv('C:/Users/Usuario/Documents/Laboratorio_6_7_ITeDA/Presentacion-Informe Avance de Proyecto/Datos Bode/Bode_data_full_chain.txt', sep="\t", skiprows=1, names=['Frequency', 'V(out_fs)'], encoding='ISO-8859-1')

# Extract the dB value and apply an offset
df['Attenuation'] = df['V(out_fs)'].apply(lambda x: float(x.split(',')[0][1:].replace('dB', '').strip())) + 6.5

# Find the peak attenuation for simulated data
max_simulated_idx = df['Attenuation'].idxmax()
max_simulated_freq = df['Frequency'].iloc[max_simulated_idx]
max_simulated_value = df['Attenuation'].iloc[max_simulated_idx]




# Create a larger figure
plt.figure(figsize=(12, 8))  # Set width and height in inches

# Scatter plot for manufacturer data
df2.plot(kind='scatter', x='frec', y='atenuation', color='blue', label='Manufacturer')

# Plotting the simulated data
plt.plot(df['Frequency'], df['Attenuation'], color='red', label='Simulated')
plt.xscale('log')  # Set x-axis to log scale
plt.xlim(1e5, 5e8)
plt.ylim(0, 55)

# Mark the highest attenuation point for simulated data
plt.scatter(max_simulated_freq, max_simulated_value, color='red', zorder=5)
plt.axvline(x=max_simulated_freq, color='red', linestyle='--')
plt.annotate(f'Freq: {max_simulated_freq:.2e} Hz', 
             xy=(max_simulated_freq, max_simulated_value), 
             xytext=(-120, -5),  # Adjusting to the left side
             textcoords='offset points', 
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10, color='black', 
             bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

# Mark the highest attenuation point for manufacturer data
plt.scatter(max_manufacturer_freq, max_manufacturer_value, color='blue', zorder=5)
plt.axvline(x=max_manufacturer_freq, color='blue', linestyle='--')
plt.annotate(f'Freq: {max_manufacturer_freq:.2e} Hz', 
             xy=(max_manufacturer_freq, max_manufacturer_value), 
             xytext=(30, -2), 
             textcoords='offset points', 
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10, color='black', 
             bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

# Set titles and labels
plt.title('Comparison of Simulated and Manufacturer Bode Diagram of the whole chain', size=11)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Attenuation (dB)')
plt.legend(loc='lower left')
plt.grid()

# Save and display the plot
plt.savefig('frequency_vs_attenuation_whole_chain_comparison_normalized.pdf', dpi=1000)
plt.show()

# %%
# Load manufacturer data
df2 = pd.read_csv('C:/Users/Usuario/Documents/Laboratorio_6_7_ITeDA/Bode-Manufacturer + Código/mag_fschain.csv', names=("frec", "atenuation"))
df2 = df2.tail(-1)
df2 = df2.astype('float')

# Find the peak attenuation for manufacturer data (manual selection of the previous point)
max_manufacturer_idx = df2['atenuation'].idxmax() - 1  # Moving to the previous point
max_manufacturer_freq = df2['frec'].iloc[max_manufacturer_idx]
max_manufacturer_value = df2['atenuation'].iloc[max_manufacturer_idx]



# Load simulated data
df = pd.read_csv('C:/Users/Usuario/Documents/Laboratorio_6_7_ITeDA/Presentacion-Informe Avance de Proyecto/Datos Bode/Bode_data_full_chain.txt', sep="\t", skiprows=1, names=['Frequency', 'V(out_fs)'], encoding='ISO-8859-1')

# Extract the dB value and apply an offset
df['Attenuation'] = df['V(out_fs)'].apply(lambda x: float(x.split(',')[0][1:].replace('dB', '').strip())) + 6.5

# Find the peak attenuation for simulated data
max_simulated_idx = df['Attenuation'].idxmax()
max_simulated_freq = df['Frequency'].iloc[max_simulated_idx]
max_simulated_value = df['Attenuation'].iloc[max_simulated_idx]

                                             

# Load real data
df3 = pd.read_csv('C:/Users/Usuario/Documents/Laboratorio_6_7_ITeDA/Presentacion-Informe Avance de Proyecto/datos_reales.csv', delimiter=";", names=("Atenuation", "Frequency"))

# Convert columns to numeric values (replace commas with dots for decimal values)
df3['Frequency'] = pd.to_numeric(df3['Frequency'].str.replace(',', '.'), errors='coerce')
df3['Atenuation'] = pd.to_numeric(df3['Atenuation'].str.replace(',', '.'), errors='coerce')

# Add 30 dB to the attenuation values
df3['Atenuation'] += 30

# Find the peak attenuation for real data
max_real_idx = df3['Atenuation'].idxmax()
max_real_freq = df3['Frequency'].iloc[max_real_idx]
max_real_value = df3['Atenuation'].iloc[max_real_idx]



# Create a larger figure
plt.figure(figsize=(12, 8))  # Set width and height in inches

# Scatter plot for manufacturer data
plt.scatter(df2['frec'], df2['atenuation'], color='blue', label='Manufacturer')

# Plot the real data
plt.scatter(df3['Frequency'], df3['Atenuation'], color='green', label='Laboratory Data')

# Plotting the simulated data
plt.plot(df['Frequency'], df['Attenuation'], color='red', label='Simulated')

plt.xscale('log')  # Set x-axis to log scale
plt.xlim(2e5, 1e8)
plt.ylim(0, 55)

# Mark the highest attenuation point for simulated data
plt.scatter(max_simulated_freq, max_simulated_value, color='red', zorder=5)
plt.axvline(x=max_simulated_freq, color='red', linestyle='--')
plt.annotate(f'Freq: {max_simulated_freq:.2e} Hz', 
             xy=(max_simulated_freq, max_simulated_value), 
             xytext=(-75, -60),  # Adjusting to the left side
             textcoords='offset points', 
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10, color='black', 
             bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

# Mark the highest attenuation point for manufacturer data
plt.scatter(max_manufacturer_freq, max_manufacturer_value, color='blue', zorder=5)
plt.axvline(x=max_manufacturer_freq, color='blue', linestyle='--')
plt.annotate(f'Freq: {max_manufacturer_freq:.2e} Hz', 
             xy=(max_manufacturer_freq, max_manufacturer_value), 
             xytext=(30, -2), 
             textcoords='offset points', 
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10, color='black', 
             bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

# Mark the highest attenuation point for real data
plt.scatter(max_real_freq, max_real_value, color='green', zorder=5)
plt.axvline(x=max_real_freq, color='green', linestyle='--')
plt.annotate(f'Freq: {max_real_freq:.2e} Hz', 
             xy=(max_real_freq, max_real_value), 
             xytext=(-160, -15),  # Adjusting annotation position
             textcoords='offset points', 
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10, color='black', 
             bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

# Set titles and labels
plt.title('Comparison of Simulated, Manufacturer, and Laboratory Data - Bode Diagram of the Whole Chain', size=16)
plt.xlabel('Frequency (Hz)', size=14)
plt.ylabel('Attenuation (dB)', size=14)
plt.legend(loc='upper left')
plt.grid()

# Save and display the plot
plt.savefig('frequency_vs_attenuation_whole_chain_comparison_with_real_data.pdf', dpi=1000)
plt.show()

# %% [markdown]
# ## Plot Full Sim

# %%
# Load the data
file_path = r'C:/Users/smili/OneDrive/Documents/GitHub/Laboratorio_6_7_ITeDA/Presentacion-Informe Avance de Proyecto/Datos Full_Sim/full_sim_with_discr.txt'
df = pd.read_csv(file_path, delim_whitespace=True)

times=100

plt.plot(df['time'], df['V(input_bode)'] * times, label=f'Input Signal x{times}', color='blue', linestyle='-', linewidth=2)
plt.plot(df['time'], df['V(out_preamp)'] * (-15), label=r'Output PreAmplifier x(-15)', color='purple', linestyle=':', linewidth=2)
plt.plot(df['time'], df['V(out)'], label=r'Discriminator', color='green', linestyle='--', linewidth=2)
plt.plot(df['time'], df['V(out_fs)'], label=r'Output FastShaper', color='red', linestyle='-.', linewidth=2)

# Add the horizontal line at 91.6 mV
threshold_value = 0.0916  # in volts
plt.axhline(y=threshold_value, color='orange', linestyle='--', label='2.5PE Threshold (91.6mV)')

plt.xlim(0,1.5e-7)
plt.title('Full Simulation Data', size=15)
plt.xlabel('Time (s)', size=13)
plt.ylabel('Voltage (V)', size=13)
plt.legend(loc='upper right')
plt.grid(True)

# Save and display the plot
#plt.savefig('full_simulation_data_plot.pdf', dpi=1000)
plt.show()
# Out:
# C:\Users\smili\AppData\Local\Temp\ipykernel_15012\3107424951.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True)

# %%
# Read the text file, using tab as the separator, and specify encoding
df = pd.read_csv('C:/Users/Usuario/OneDrive/Desktop/ITeDA/Presentacion-Informe Avance de Proyecto/Bode_Full_Chain.txt', sep="\t", skiprows=1, names=['Frequency', 'V(out_fs)'], encoding='ISO-8859-1')

# Check the first few rows to understand the structure
print(df.head())

# Extract the first element of V(out_fs), which is the dB value
df['Attenuation'] = df['V(out_fs)'].apply(lambda x: float(x.split(',')[0][1:].replace('dB', '').strip()))  # Clean the dB part

# Plotting
plt.figure(figsize=(16, 10))
plt.plot(df['Frequency'], df['Attenuation'], color='red')
plt.title('Simulated Bode Diagram of the whole chain', size=15)
plt.xlabel('Frequency (Hz)', size=13)
plt.ylabel('Attenuation (dB)', size=13)
plt.xlim(300000, 80000000)
plt.grid()
plt.savefig('frequency_vs_attenuation_whole_chain_zoom_nolog.png', dpi=1000)
plt.show()
# Out:
#        Frequency                                       V(out_fs)
# 0  100000.000000  (3.92188474524891e+00dB,8.90926015303044e+01°)
# 1  100023.028502  (3.92388455706964e+00dB,8.90923925795384e+01°)
# 2  100046.062307  (3.92588436880371e+00dB,8.90921835806606e+01°)
# 3  100069.101417  (3.92788418045107e+00dB,8.90919745336601e+01°)
# 4  100092.145832  (3.92988399201169e+00dB,8.90917654385258e+01°)

# %% [markdown]
# ## 1PE

# %%
# Read the text file, specifying the delimiter as a comma
df = pd.read_csv('Scripts/photon_data_1_photoequivalent.txt', header=None)

# Print the first few rows of the dataframe to check the data
print(df.head())

# Extract the time and amplitude values
t_values = df[0]  # First column
data = df[1]     # Second column

# Plot the resulting function
plt.plot(t_values, data, color='red', label='Output Signal', linewidth=2)
plt.title('Plot of 1 Individual Photon')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (V)')
plt.grid(True)
plt.legend()
plt.savefig('1pe.png', dpi=1000)
# Out:
#               0         1
# 0  0.000000e+00  0.000000
# 1  6.671114e-11  0.000125
# 2  1.334223e-10  0.000232
# 3  2.001334e-10  0.000325
# 4  2.668446e-10  0.000404
